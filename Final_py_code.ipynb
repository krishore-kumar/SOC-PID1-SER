# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense,Input
import librosa as lb
import pandas as pd
import librosa.display
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelBinarizer, StandardScaler

# %%
def extract_features(main_dir, list_of_features):
    features_list = []
    labels = []

    for subfolder in os.listdir(main_dir):
        subfolder_path = os.path.join(main_dir, subfolder)
        if os.path.isdir(subfolder_path):
            # Iterate over each audio file in the subfolder
            for filename in os.listdir(subfolder_path):
                if filename.endswith('.wav'):
                    file_path = os.path.join(subfolder_path, filename)
                    
                    y, sr = librosa.load(file_path)

                    features = []
                    if 'mfcc' in list_of_features:
                        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
                        features.extend(mfcc.mean(axis=1))

                    if 'chroma' in list_of_features:
                        stft = np.abs(librosa.stft(y))
                        chroma = librosa.feature.chroma_stft(S=stft, sr=sr)
                        features.extend(chroma.mean(axis=1))

                    if 'melspectrogram' in list_of_features:
                        mel_spect = librosa.feature.melspectrogram(y=y, sr=sr)
                        mel_spect_db = librosa.power_to_db(mel_spect, ref=np.max)
                        features.extend(mel_spect_db.mean(axis=1))

                    features_list.append(features)
                    labels.append(filename[7])  

    return features_list, labels

# %%
def load_data(test_size1=0.2):
    filename = r'D:\IITB work\SoC-Speech Emotion Recognition\week 5&6\Submission\Audio_Speech_Actors_01-24'
    filename1 = r'D:\IITB work\SoC-Speech Emotion Recognition\week 5&6\Submission\Audio_Song_Actors_01-24'
    listf = ['mfcc', 'chroma', 'melspectrogram']
    
    features, labels = extract_features(main_dir=filename, list_of_features=listf)
    features1, labels1 = extract_features(main_dir=filename1, list_of_features=listf)
    
    features_array = np.array(features, dtype=np.float32)
    labels_array = np.array(labels)
    features_array1 = np.array(features1, dtype=np.float32)
    labels_array1 = np.array(labels1)
    
    features_array2 = np.concatenate((features_array, features_array1), axis=0)
    labels_array2 = np.concatenate((labels_array, labels_array1), axis=0)
    
    scaler = StandardScaler()
    features_array2 = scaler.fit_transform(features_array2)
    
    lb = LabelBinarizer()
    labels_one_hot = lb.fit_transform(labels_array2)
    
    X_train, X_test, y_train, y_test = train_test_split(features_array2, labels_one_hot, test_size=test_size1, random_state=42)
    return X_train, X_test, y_train, y_test, lb

# %%
X_train, X_test, y_train, y_test, lb = load_data()

# %%
model = tf.keras.Sequential([
    Dense(300, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(y_train.shape[1], activation='softmax')
])
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])  
model.fit(X_train, y_train, epochs=200, batch_size=256, validation_split=0.1)
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=2)
print(f'Test Accuracy: {test_accuracy*100:.4f}')
# Out:
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.1732 - loss: 2.1734 - val_accuracy: 0.2893 - val_loss: 1.7548
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3576 - loss: 1.6753 - val_accuracy: 0.4010 - val_loss: 1.6167
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4786 - loss: 1.4479 - val_accuracy: 0.4569 - val_loss: 1.4915
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5354 - loss: 1.3151 - val_accuracy: 0.5025 - val_loss: 1.3990
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5912 - loss: 1.2186 - val_accuracy: 0.5431 - val_loss: 1.3451
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.
200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9977 - loss: 0.0797 - val_accuracy: 0.7868 - val_loss: 0.6902
# Epoch 100/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9988 - loss: 0.0754 - val_accuracy: 0.7970 - val_loss: 0.6875
# Epoch 101/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9984 - loss: 0.0769 - val_accuracy: 0.7919 - val_loss: 0.6897
# Epoch 102/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9992 - loss: 0.0766 - val_accuracy: 0.7919 - val_loss: 0.6837
# Epoch 103/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9992 - loss: 0.0733 - val_accuracy: 0.7716 - val_loss: 0.6942
# Epoch 104/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0728 - val_accuracy: 0.7868 - val_loss: 0.6865
# Epoch 105/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9990 - loss: 0.0697 - val_accuracy: 0.7766 - val_loss: 0.6937
# Epoch 106/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0698 - val_accuracy: 0.8020 - val_loss: 0.6939
# Epoch 107/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9992 - loss: 0.0681 - val_accuracy: 0.7868 - val_loss: 0.6971
# Epoch 108/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0661 - val_accuracy: 0.7919 - val_loss: 0.6869
# Epoch 109/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9983 - loss: 0.0651 - val_accuracy: 0.7766 - val_loss: 0.6966
# Epoch 110/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9994 - loss: 0.0623 - val_accuracy: 0.7919 - val_loss: 0.6875
# Epoch 111/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9987 - loss: 0.0621 - val_accuracy: 0.7970 - val_loss: 0.6973
# Epoch 112/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9997 - loss: 0.0579 - val_accuracy: 0.7817 - val_loss: 0.6888
# Epoch 113/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0590 - val_accuracy: 0.7919 - val_loss: 0.6985
# Epoch 114/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0557 - val_accuracy: 0.7868 - val_loss: 0.6920
# Epoch 115/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9998 - loss: 0.0565 - val_accuracy: 0.7868 - val_loss: 0.7042
# Epoch 116/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0557 - val_accuracy: 0.7919 - val_loss: 0.6893
# Epoch 117/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0540 - val_accuracy: 0.7817 - val_loss: 0.7061
# Epoch 118/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9997 - loss: 0.0523 - val_accuracy: 0.7919 - val_loss: 0.6942
# Epoch 119/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0519 - val_accuracy: 0.7817 - val_loss: 0.7038
# Epoch 120/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9994 - loss: 0.0496 - val_accuracy: 0.7817 - val_loss: 0.6984
# Epoch 121/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0497 - val_accuracy: 0.7868 - val_loss: 0.7096
# Epoch 122/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0475 - val_accuracy: 0.7919 - val_loss: 0.7008
# Epoch 123/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0494 - val_accuracy: 0.7868 - val_loss: 0.7035
# Epoch 124/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0477 - val_accuracy: 0.7919 - val_loss: 0.6987
# Epoch 125/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9994 - loss: 0.0479 - val_accuracy: 0.7970 - val_loss: 0.6995
# Epoch 126/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0469 - val_accuracy: 0.7716 - val_loss: 0.7098
# Epoch 127/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0446 - val_accuracy: 0.7868 - val_loss: 0.6995
# Epoch 128/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.0437 - val_accuracy: 0.7919 - val_loss: 0.7058
# Epoch 129/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0422 - val_accuracy: 0.7868 - val_loss: 0.7041
# Epoch 130/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0403 - val_accuracy: 0.7919 - val_loss: 0.7063
# Epoch 131/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0399 - val_accuracy: 0.7868 - val_loss: 0.7063
# Epoch 132/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9998 - loss: 0.0409 - val_accuracy: 0.7868 - val_loss: 0.7080
# Epoch 133/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0413 - val_accuracy: 0.7919 - val_loss: 0.7112
# Epoch 134/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0381 - val_accuracy: 0.7919 - val_loss: 0.7044
# Epoch 135/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0362 - val_accuracy: 0.7868 - val_loss: 0.7131
# Epoch 136/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0368 - val_accuracy: 0.8020 - val_loss: 0.7126
# Epoch 137/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9997 - loss: 0.0365 - val_accuracy: 0.7817 - val_loss: 0.7094
# Epoch 138/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0357 - val_accuracy: 0.7919 - val_loss: 0.7171
# Epoch 139/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0365 - val_accuracy: 0.7868 - val_loss: 0.7119
# Epoch 140/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0362 - val_accuracy: 0.7919 - val_loss: 0.7148
# Epoch 141/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0355 - val_accuracy: 0.7919 - val_loss: 0.7187
# Epoch 142/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0330 - val_accuracy: 0.7919 - val_loss: 0.7163
# Epoch 143/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0339 - val_accuracy: 0.7868 - val_loss: 0.7156
# Epoch 144/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0321 - val_accuracy: 0.7919 - val_loss: 0.7243
# Epoch 145/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0321 - val_accuracy: 0.7919 - val_loss: 0.7102
# Epoch 146/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0319 - val_accuracy: 0.7868 - val_loss: 0.7173
# Epoch 147/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0309 - val_accuracy: 0.7919 - val_loss: 0.7242
# Epoch 148/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0300 - val_accuracy: 0.7868 - val_loss: 0.7212
# Epoch 149/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0295 - val_accuracy: 0.7919 - val_loss: 0.7203
# Epoch 150/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.7919 - val_loss: 0.7201
# Epoch 151/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 0.7868 - val_loss: 0.7330
# Epoch 152/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0294 - val_accuracy: 0.7868 - val_loss: 0.7150
# Epoch 153/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 0.7919 - val_loss: 0.7308
# Epoch 154/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0268 - val_accuracy: 0.7919 - val_loss: 0.7244
# Epoch 155/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.7919 - val_loss: 0.7296
# Epoch 156/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0263 - val_accuracy: 0.7919 - val_loss: 0.7252
# Epoch 157/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0266 - val_accuracy: 0.7868 - val_loss: 0.7237
# Epoch 158/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0253 - val_accuracy: 0.7919 - val_loss: 0.7333
# Epoch 159/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0261 - val_accuracy: 0.7970 - val_loss: 0.7262
# Epoch 160/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0256 - val_accuracy: 0.8020 - val_loss: 0.7380
# Epoch 161/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0259 - val_accuracy: 0.7919 - val_loss: 0.7270
# Epoch 162/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0242 - val_accuracy: 0.7868 - val_loss: 0.7402
# Epoch 163/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 0.7919 - val_loss: 0.7314
# Epoch 164/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0240 - val_accuracy: 0.7919 - val_loss: 0.7375
# Epoch 165/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.7919 - val_loss: 0.7344
# Epoch 166/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 0.7868 - val_loss: 0.7352
# Epoch 167/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0218 - val_accuracy: 0.7919 - val_loss: 0.7453
# Epoch 168/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.7970 - val_loss: 0.7310
# Epoch 169/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 0.7919 - val_loss: 0.7392
# Epoch 170/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0218 - val_accuracy: 0.7970 - val_loss: 0.7344
# Epoch 171/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.7868 - val_loss: 0.7491
# Epoch 172/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0212 - val_accuracy: 0.7970 - val_loss: 0.7328
# Epoch 173/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.7868 - val_loss: 0.7464
# Epoch 174/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 0.7919 - val_loss: 0.7410
# Epoch 175/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0201 - val_accuracy: 0.7919 - val_loss: 0.7390
# Epoch 176/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0208 - val_accuracy: 0.7970 - val_loss: 0.7494
# Epoch 177/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 0.7919 - val_loss: 0.7401
# Epoch 178/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 0.7868 - val_loss: 0.7540
# Epoch 179/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.7868 - val_loss: 0.7430
# Epoch 180/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.7919 - val_loss: 0.7453
# Epoch 181/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.7970 - val_loss: 0.7526
# Epoch 182/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 0.7970 - val_loss: 0.7526
# Epoch 183/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 0.7970 - val_loss: 0.7435
# Epoch 184/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0176 - val_accuracy: 0.7919 - val_loss: 0.7527
# Epoch 185/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 0.8020 - val_loss: 0.7493
# Epoch 186/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 0.7970 - val_loss: 0.7570
# Epoch 187/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0181 - val_accuracy: 0.7970 - val_loss: 0.7496
# Epoch 188/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.7868 - val_loss: 0.7590
# Epoch 189/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 0.7970 - val_loss: 0.7497
# Epoch 190/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.7817 - val_loss: 0.7596
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 0.8020 - val_loss: 0.7560
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 0.8020 - val_loss: 0.7581
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.8020 - val_loss: 0.7474
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 0.7970 - val_loss: 0.7578
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 0.8020 - val_loss: 0.7627
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.8020 - val_loss: 0.7544
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.7970 - val_loss: 0.7585
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.8020 - val_loss: 0.7663
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.7970 - val_loss: 0.7568
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.7970 - val_loss: 0.7665
# 16/16 - 0s - 2ms/step - accuracy: 0.7454 - loss: 0.9615
# Test Accuracy: 74.5418

# %%
print(f'Test Accuracy: {test_accuracy*100:.4f}')
# Out:
# Test Accuracy: 74.5418

# %%
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)
print(classification_report(y_test_labels, y_pred_labels))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.80        38
#            1       0.78      0.81      0.80        81
#            2       0.77      0.68      0.72        73
#            3       0.68      0.76      0.72        71
#            4       0.81      0.83      0.82        69
#            5       0.71      0.71      0.71        80
#            6       0.64      0.60      0.62        45
#            7       0.71      0.79      0.75        34
#
#     accuracy                           0.75       491
#    macro avg       0.75      0.74      0.74       491
# weighted avg       0.75      0.75      0.75       491
